# %% [markdown]
# # `Práctica 7 Pandas`
#
# > Añadir blockquote
#
# > Añadir blockquote

# %% [markdown]
# ## Biblioteca Pandas

# %% [markdown]
# ## Introducción

# %% [markdown]
# * Las filas y columnas están identificados con etiquetas, además de simples índices enteros
# * Es importante entender un poco de las estructuras de Pandas
# * Tres estructuras importantes:
#     + `Series`
#     + `DataFrame`
#     + `Index`

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Objetos `Series` en Pandas
#
# * Puede pensarse como una array de una sola dimensión indexado.
# * Puede ser creado desde una lista:

# %%
edades = [1,4,5,6,17,87]
pandeado = pd.Series(edades)
pandeado
print(pandeado)
# Out:
# 0     1
# 1     4
# 2     5
# 3     6
# 4    17
# 5    87
# dtype: int64

# %% [markdown]
# * Una ``Series`` encapsula tanto una secuencia de valores como una de índices.
# * Podemos acceder a ellos con los atributos `values` e `index`

# %%
pandeado.values
# Out:
# array([ 1,  4,  5,  6, 17, 87])

# %% [markdown]
# * Un `index` es un objeto similar a un array.

# %%
pandeado.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %% [markdown]
# * Podemos acceder a una `Series` a través del índice asociado de forma similar a los arrays de Numpy: con los `[]`

# %%
pandeado[3]
# Out:
# np.int64(6)

# %%
print(pandeado[2])
# Out:
# 5

# %% [markdown]
# ### ``Series`` como generalización de un array de  NumPy

# %% [markdown]
# * La diferencia esencial con un array de Numpy es que mientras que el array tiene un índice entero *"implícitamente definido"*, una `Series` de Pandas tiene un índice asociado a los valores *que está definido de forma explícita*
# * Este índice explícito le da a una `Series` capacidades adicionales.
# * El índice explícito no tiene por qué ser un entero y tampoco todos sus valores tienen que ser necesariamente únicos.

# %% [markdown]
# * Pueden ser `strings`

# %%
dias = pd.Series([1,2,3,4,5],
                 index=["Lunes", "Martes", "Miercoles", "Jueves", "Viernes"])
dias
# Out:
# Lunes        1
# Martes       2
# Miercoles    3
# Jueves       4
# Viernes      5
# dtype: int64

# %%
dias.index
# Out:
# Index(['Lunes', 'Martes', 'Miercoles', 'Jueves', 'Viernes'], dtype='str')

# %% [markdown]
# * Y podemos acceder simplemente:

# %%
dias["Miercoles"]
# Out:
# np.int64(3)

# %% [markdown]
# * O puede ser una secuencia no contigua de `int`s

# %%
intts = pd.Series([1, 15, 2, 30],
                  index=[8, 3, 14, 2])
intts
# Out:
# 8      1
# 3     15
# 14     2
# 2     30
# dtype: int64

# %%
print("Por clave: ", intts[2])
print("Por posicion: ", intts.iloc[2])
# Out:
# Por clave:  30
# Por posicion:  2

# %% [markdown]
# ### ``Series`` como un `dict` especializado

# %% [markdown]
# * Un `dict` es una estructura que mapea un set de keys arbitrarias a un set de valores de un tipo.
# * Puede hacerse, entonces, una analogía entre una `Series` y un `dict`

# %%
population_dict = {'California': 38332521,
                   'Texas': 26448193,
                   'New York': 19651127,
                   'Florida': 19552860,
                   'Illinois': 12882135}
# population_dict
populationn = pd.Series(population_dict)
populationn
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %%
# population_dict.values()
populationn.values
# Out:
# array([38332521, 26448193, 19651127, 19552860, 12882135])

# %%
# population_dict.keys()
populationn.index
# Out:
# Index(['California', 'Texas', 'New York', 'Florida', 'Illinois'], dtype='str')

# %% [markdown]
# * Puede crearse una `Series` a partir de un `dict`: el índice se toma de las keys.
# * Así, puede accederse de forma análoga a un `dict`.

# %%
populationn["Texas"]
# Out:
# np.int64(26448193)

# %% [markdown]
# * A diferencia de un `dict` una `Series` soporta algunas operaciones del estilo de un array, como por ejemplo, slicing:

# %%
populationn["New York":"Illinois"]
# Out:
# New York    19651127
# Florida     19552860
# Illinois    12882135
# dtype: int64

# %% [markdown]
# * Si creamos una `Series` con una lista de strings se respeta el orden de las columnas, mientras que las claves de los `dicts` se ordenan alfabéticamente al crearse la `Series`

# %%
estados_list = ['Illinois','Texas','New York', 'Florida', 'California']
estados_pop = [12882135, 26448193, 19651127, 19552860, 38332521]
estados = pd.Series(estados_pop, index= estados_list)

# %%
estados['New York':'California']
# Out:
# New York      19651127
# Florida       19552860
# California    38332521
# dtype: int64

# %% [markdown]
# ### Construyendo objetos Series

# %% [markdown]
# * Podemos construir `Series` desde cero. La forma general de hacerlo es la siguiente:
#
# ```python
# >>> pd.Series(data, index=index)
# ```
# * `index` es un argumento opcional y `data` puede ser varias cosas

# %%
# Una lista o un array de Numpy
pd.Series([2, 4, 6])
# Out:
# 0    2
# 1    4
# 2    6
# dtype: int64

# %%
# Un escalar repetido a lo largo de un índice
pd.Series(5, index = [100, 200, 300])
# Out:
# 100    5
# 200    5
# 300    5
# dtype: int64

# %%
pd.Series({2:'a', 1:'b', 3:'c'})
# Out:
# 2    a
# 1    b
# 3    c
# dtype: str

# %%
# En cada caso, podría usarse el índice explícitamente si lo que se busca es otro resultado
pd.Series({2:'a', 1:'b', 3:'c'}, index=[3, 2])
# Out:
# 3    c
# 2    a
# dtype: str

# %% [markdown]
# ## Objeto `DataFrame`

# %% [markdown]
# * Otra estructura fundamental.
# * También puede ser pensada como una generalización de un array de NumPy o como un tipo especial de diccionario.

# %% [markdown]
# ### `DataFrame` como un array de Numpy

# %% [markdown]
# * Un `DataFrame` es un tipo análogo a una `Series` en dos dimensiones y, por lo tanto, puede ser una pensado tanto como una generalización de un array de Numpy o como un conjunto de `Series` alineados. Es decir, que tienen el mismo índice.
#
# * Para demostrar esto generemos una `Serie` con el área de algunos estados:

# %%
area_dict = {'California': 423967, 'Texas': 695662, 'New York': 141297,
             'Florida': 170312, 'Illinois': np.nan}
area = pd.Series(area_dict)
area
# Out:
# California    423967.0
# Texas         695662.0
# New York      141297.0
# Florida       170312.0
# Illinois           NaN
# dtype: float64

# %%
populationn
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %% [markdown]
# * Ahora, podemos usar un diccionario para construir un objeto bidimensional conteniendo toda la información.

# %%
estados = pd.DataFrame({'population': populationn,
                        'area': area})
estados
# Out:
#             population      area
# California    38332521  423967.0
# Texas         26448193  695662.0
# New York      19651127  141297.0
# Florida       19552860  170312.0
# Illinois      12882135       NaN

# %% [markdown]
# Al igual que las ``Series``, un ``DataFrame`` posee un atributo ``index``:

# %%
estados.index[2]
# Out:
# 'New York'

# %% [markdown]
# Además, tiene un atributo ``columns``, que es un objeto ``Index`` conteniendo las etiquetas de columnas:

# %%
estados.columns[1]
# Out:
# 'area'

# %%
estados['densidad'] = estados['population'] / estados['area']
estados
# Out:
#             population      area    densidad
# California    38332521  423967.0   90.413926
# Texas         26448193  695662.0   38.018740
# New York      19651127  141297.0  139.076746
# Florida       19552860  170312.0  114.806121
# Illinois      12882135       NaN         NaN

# %% [markdown]
# ### DataFrame como un diccionario especializado

# %% [markdown]
# * De forma similar, podemos pensar al `DataFrame` como un diccionario:
#
#     - Un diccionario mapea una key con un valor
#     - Un `DataFrame` mapea un nombre de columna con una `Series` de datos.
#
#
# * Por ejemplo, pedir el atributo `area` del `DataFrame` `estados` devuelve una `Series`.

# %%
estados['area']
# Out:
# California    423967.0
# Texas         695662.0
# New York      141297.0
# Florida       170312.0
# Illinois           NaN
# Name: area, dtype: float64

# %% [markdown]
# ### Construyendo objetos `DataFrame`

# %% [markdown]
# #### Desde una `Series` simple:

# %%
pd.DataFrame(populationn, columns=['population'])
# Out:
#             population
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135

# %% [markdown]
# #### Desde una lista de dicts

# %%
# listDicts = [{'hawai': 34}, {'gibraltar': 99}, {'venezuela': 167}, {'kyoto': 3}]
# pd.DataFrame(listDicts)

listComp = [{'a': i, 'b': 1.5 * i}
            for i in range(8)]
#* Lo mismo que hacer: 
#*   listComp = []
#*   for i in range(8):
#*       listComp.append({'a': i, 'b': 1.5 * i})
# listComp

pd.DataFrame(listComp)
# Out:
#    a     b
# 0  0   0.0
# 1  1   1.5
# 2  2   3.0
# 3  3   4.5
# 4  4   6.0
# 5  5   7.5
# 6  6   9.0
# 7  7  10.5

# %% [markdown]
# * Notar que incluso si alguna key está perdida en el diccionario, Pandas llena con `NaN` el valor:

# %%
pd.DataFrame([{'a': 1, 'b': 2}, {'b': 3, 'c': 4}])
# Out:
#      a  b    c
# 0  1.0  2  NaN
# 1  NaN  3  4.0

# %% [markdown]
# #### De un dict de `Series`

# %%
pd.DataFrame({'population': populationn,
            'area': area})
# Out:
#             population      area
# California    38332521  423967.0
# Texas         26448193  695662.0
# New York      19651127  141297.0
# Florida       19552860  170312.0
# Illinois      12882135       NaN

# %% [markdown]
# #### Desde un array Numpy de dos dimensiones

# %%
numpyA = np.array([[2,4,6], [1,3,5]])
numpyA
pd.DataFrame(numpyA)
# Out:
#    0  1  2
# 0  2  4  6
# 1  1  3  5

# %% [markdown]
# ## El objeto `Index`

# %% [markdown]
# * Un `Index` puede ser pensado como un _array inmutable_  o como un set ordenado
# * Para ilustrar las implicancias de este punto pensemos en el siguiente ejemplo en el que construimos un `Index` desde una lista de enteros.
# * Los `DataFrames` tienen un `Index` que describe a las filas y otro que describe a las columnas.
# * Al  `Index` de filas se accede con `df.index` y al de columna `df.columns`.

# %%
ind = pd.Index([2, 3, 5, 7, 11])
ind
# Out:
# Index([2, 3, 5, 7, 11], dtype='int64')

# %% [markdown]
# ### `Index` como una array inmutable
#
# * Podemos indexar y hacer slicing de forma similar a un array

# %%
ind[3]
# Out:
# np.int64(7)

# %%
deADos = ind[::3] #saltando de a dos
deAUno = ind[::2] #saltando de a uno
print(deADos)
print(deAUno)
# Out:
# Index([2, 7], dtype='int64')
# Index([2, 5, 11], dtype='int64')

# %% [markdown]
# Los `Index` tienen atributos similares a los arrays de Numpy

# %%
print(ind.size, ind.shape, ind.ndim, ind.dtype)
# Out:
# 5 (5,) 1 int64

# %% [markdown]
# Una diferencia entre los ``Index`` y los arrays de NumPy es que los primeros son *inmutables*:

# %%
#! ind[1] = 0 Esto no funciona

# %% [markdown]
# ### `Index` como un set ordenado
#
# * Se pueden utilizar operaciones de conjuntos con los ``Index`` siguiendo las convenciones de Python

# %%
indA = pd.Index([1, 3, 5, 7, 9])
indB = pd.Index([2, 3, 5, 7, 11])

# %%
#* Forma vieja:
# Interseccion = indA & indB
# Union = indA | indB
# Dif_Simetrica = indA ^ indB

Interseccion = indA.intersection(indB)
Union = indA.union(indB)
Dif_Simetrica = indA.symmetric_difference(indB)

print(Interseccion)
print(Union)
print(Dif_Simetrica)
# Out:
# Index([3, 5, 7], dtype='int64')
# Index([1, 2, 3, 5, 7, 9, 11], dtype='int64')
# Index([1, 2, 9, 11], dtype='int64')

# %% [markdown]
# ### Series y DataFrames

# %%
import pandas as pd

objMuestra = pd.Series([1,4,5,6,7])
objMuestra
# Out:
# 0    1
# 1    4
# 2    5
# 3    6
# 4    7
# dtype: int64

# %%
animales = ['Raton', 'Cabra', 'Leon', 'Hormiga']
colores = ['Azul', 'Gris', 'Rojo', 'Amarillo']
#* Los dos tienen que ser del mismo tamaño para hacer una serie.

objJunto = pd.Series(colores, index=animales)
objJunto
# Out:
# Raton          Azul
# Cabra          Gris
# Leon           Rojo
# Hormiga    Amarillo
# dtype: str

# %% [markdown]
# DataFrames

# %%
d = {'tipo_vivienda': ['casa', 'departamento'], 'm2': [35, 49]}
df = pd.DataFrame(data=d)
df
# Out:
#   tipo_vivienda  m2
# 0          casa  35
# 1  departamento  49

# %% [markdown]
# ### Cargando datos

# %%
df = pd.read_csv('fifa-statistics.csv')
df
#! No tenemos el archivo para cargarlo.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df = pd.read_csv('fifa-statistics.csv')
#       2 df
#
# File ~/IES/2do-CD/venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~/IES/2do-CD/venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~/IES/2do-CD/venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~/IES/2do-CD/venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~/IES/2do-CD/venv/lib/python3.12/site-packages/pandas/io/common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'fifa-statistics.csv'

# %% [markdown]
# ## Selección e Indexing

# %% [markdown]
# ### loc e iloc

# %% [markdown]
# ## Análisis descriptivo en Pandas

# %% [markdown]
# ### describe, info y shape

# %% [markdown]
# ### unique y value_counts()

# %% [markdown]
# ### count, min, max, mean, median, std y corr

# %% [markdown]
# ## Precentiles

# %% [markdown]
# Son una medida usada en estadística que indica el valor de la variable por debajo del cual se encuentra un porcentaje dado de observaciones. Ahora los Cuantiles son puntos tomados a intervalos regulares de la función de distribución de una variable aleatoria. Los cuantiles podemos usarlos por grupos que dividan la distribución en partes iguales; obteniendo sus hijos, los Percentiles, Deciles y Quartiles.

# %% [markdown]
# ### Ordenando datos

# %% [markdown]
# ### Tablas Dinamicas

# %% [markdown]
# ## Combinando datasets

# %% [markdown]
# ### concat y append

# %% [markdown]
# ### Merge

# %% [markdown]
# ## Apply y Map

# %% [markdown]
# ### apply

# %% [markdown]
# ### applymap

# %% [markdown]
# ## Missing values

# %% [markdown]
# ### Filtrando valores faltantes

# %% [markdown]
# ### Completando valores

# %% [markdown]
# ### Borrando duplicados
